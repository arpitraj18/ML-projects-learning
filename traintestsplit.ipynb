# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\arpit\Downloads\carprices.csv")
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
# %matplotlib inline
plt.scatter(df[['Age(yrs)']],df.Mileage)
plt.show()

# %%
# %matplotlib inline
plt.scatter(df[['Age(yrs)']],df[['Sell Price($)']])
plt.show()

# %%
x=df[["Mileage",'Age(yrs)']]

# %%
y=df[['Sell Price($)']]

# %%
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 4     46000         4
# 5     59000         5
# 15    25400         3
# 12    59000         5
# 14    82450         7
# 3     22500         2
# 13    58780         4
# 19    52000         5
# 1     35000         3
# 11    79000         7
# 10    83000         7
# 8     91000         8
# 7     72000         6
# 9     67000         6

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
#     Sell Price($)
# 18          12800
# 16          35500
# 0           18000
# 17          19700
# 2           26100
# 6           32000

# %%
reg.predict(x_test)
# Out:
# array([[14467.54275291],
#        [37269.96982357],
#        [21725.64337341],
#        [22838.49251385],
#        [26085.2037007 ],
#        [27438.00002855]])

# %%
reg.score(x_test,y_test)
# Out:
# 0.8674260242226113
